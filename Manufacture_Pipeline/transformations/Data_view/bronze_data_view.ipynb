# %%
# %sql
DROP TABLE IF EXISTS manufacture.bronze.product_bronze;

# %%
# %sql
DROP MATERIALIZED VIEW IF EXISTS manufacture.bronze.product_bronze;

# %%
# %sql
select * from manufacture.bronze.product_bronze LIMIT 10;

# %%
# %sql
select count(*) as total_rows from manufacture.bronze.product_bronze
